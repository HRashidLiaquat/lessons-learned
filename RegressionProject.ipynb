# %% [markdown]
# <a href="https://colab.research.google.com/github/HRashidLiaquat/lessons-learned/blob/Regression_Project/RegressionProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Liner Regression**

# %% [markdown]
# **Complete Work Flow**
#
# 0. Important libraries
# 1. Get data ready (turn into tensors)
# 2. Build A Linear Regression model
# 3. Pick a loss function and optimizer
# 4. Build a training loop
# 5. Evalate your model
# 6. test model with new data point
# 7. save model

# %% [markdown]
# **0. import important libraries**

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **1.Get Data Ready (turn into tensor)**
# ![image.png](data:image/png;base64,...)

# %%
x_train = np.array([[3.3], [4.4], [5.5], [6.71], [6.93],
                    [4.168], [9.779], [6.182], [7.59], [2.167],
                    [7.042], [10.791], [5.313], [7.997], [3.1]], dtype = np.float32)

y_train = np.array([[1.7], [2.76], [2.09], [3.19], [1.694], [1.573],
                    [3.366], [2.596], [2.53], [1.221], [2.827],
                    [3.465], [1.65], [2.904], [1.3]], dtype = np.float32 )

# %%
x_train
# Out:
# array([[ 3.3  ],
#        [ 4.4  ],
#        [ 5.5  ],
#        [ 6.71 ],
#        [ 6.93 ],
#        [ 4.168],
#        [ 9.779],
#        [ 6.182],
#        [ 7.59 ],
#        [ 2.167],
#        [ 7.042],
#        [10.791],
#        [ 5.313],
#        [ 7.997],
#        [ 3.1  ]], dtype=float32)

# %%
y_train
# Out:
# array([[1.7  ],
#        [2.76 ],
#        [2.09 ],
#        [3.19 ],
#        [1.694],
#        [1.573],
#        [3.366],
#        [2.596],
#        [2.53 ],
#        [1.221],
#        [2.827],
#        [3.465],
#        [1.65 ],
#        [2.904],
#        [1.3  ]], dtype=float32)

# %% [markdown]
# **Show Raw dataset in figure**

# %%
fig = plt.figure(figsize = (10,5))
plt.plot(x_train, y_train, 'ro', label = 'Original data')
plt.xlabel('Hours Studies')
plt.ylabel('Exam Score')
plt.legend()
plt.title('Exam Score Prediction')
plt.show()

# %% [markdown]
# **Get DataSet (Convert into tensor)**

# %%
x_train = torch.from_numpy(x_train)
y_train = torch.from_numpy(y_train)

# %%
x_train,y_train
# Out:
# (tensor([[ 3.3000],
#          [ 4.4000],
#          [ 5.5000],
#          [ 6.7100],
#          [ 6.9300],
#          [ 4.1680],
#          [ 9.7790],
#          [ 6.1820],
#          [ 7.5900],
#          [ 2.1670],
#          [ 7.0420],
#          [10.7910],
#          [ 5.3130],
#          [ 7.9970],
#          [ 3.1000]]),
#  tensor([[1.7000],
#          [2.7600],
#          [2.0900],
#          [3.1900],
#          [1.6940],
#          [1.5730],
#          [3.3660],
#          [2.5960],
#          [2.5300],
#          [1.2210],
#          [2.8270],
#          [3.4650],
#          [1.6500],
#          [2.9040],
#          [1.3000]]))

# %% [markdown]
# **2. Build a Linear Regression model**

# %%
class LinearRegression(nn.Module):
  def __ini__(self):
    super().__init__()
    self.linear=nn.Linear(1,1)

    def forward(self,x):
      out=self.linear(x)
      return out
